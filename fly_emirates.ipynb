# %%
import pandas as pd

# %%
flights = pd.read_csv(
    "C:\\Users\\HP\\Desktop\\Downloads\\flights.csv",
    low_memory=False
)

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
flights.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_REASON    5729195
# LATE_AIRCRAFT_DELAY    4755640
# WEATHER_DELAY          4755640
# AIRLINE_DELAY          4755640
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# ELAPSED_TIME            105071
# AIR_TIME                105071
# ARRIVAL_DELAY           105071
# WHEELS_ON                92513
# TAXI_IN                  92513
# ARRIVAL_TIME             92513
# WHEELS_OFF               89047
# TAXI_OUT                 89047
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAIL_NUMBER              14721
# SCHEDULED_TIME               6
# DESTINATION_AIRPORT          0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# MONTH                        0
# ORIGIN_AIRPORT               0
# SCHEDULED_DEPARTURE          0
# YEAR                         0
# SCHEDULED_ARRIVAL            0
# DISTANCE                     0
# DIVERTED                     0
# ...

# %%
flights.duplicated().sum()
# Out:
# np.int64(0)

# %%
flights[['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT']].head()
# Out:
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0      AS            ANC                 SEA
# 1      AA            LAX                 PBI
# 2      US            SFO                 CLT
# 3      AA            LAX                 MIA
# 4      AS            SEA                 ANC

# %%
flights['ORIGIN_AIRPORT'].dtype
# Out:
# dtype('O')

# %%
flights['CANCELLED'].value_counts()
# Out:
# CANCELLED
# 0    5729195
# 1      89884
# Name: count, dtype: int64

# %%
flights['DIVERTED'].value_counts()
# Out:
# DIVERTED
# 0    5803892
# 1      15187
# Name: count, dtype: int64

# %%
flights.columns = flights.columns.str.strip()

# %%
flights['TAIL_NUMBER'] = flights['TAIL_NUMBER'].fillna('Unknown')

# %%
delay_cols = [
    'AIR_SYSTEM_DELAY',
    'SECURITY_DELAY',
    'AIRLINE_DELAY',
    'LATE_AIRCRAFT_DELAY',
    'WEATHER_DELAY'
]

flights[delay_cols] = flights[delay_cols].fillna(0)

# %%
flights.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_REASON    5729195
# ELAPSED_TIME            105071
# ARRIVAL_DELAY           105071
# AIR_TIME                105071
# WHEELS_ON                92513
# TAXI_IN                  92513
# ARRIVAL_TIME             92513
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# DEPARTURE_DELAY          86153
# DEPARTURE_TIME           86153
# SCHEDULED_TIME               6
# TAIL_NUMBER                  0
# MONTH                        0
# YEAR                         0
# DESTINATION_AIRPORT          0
# ORIGIN_AIRPORT               0
# SCHEDULED_DEPARTURE          0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# DISTANCE                     0
# SCHEDULED_ARRIVAL            0
# DIVERTED                     0
# CANCELLED                    0
# AIR_SYSTEM_DELAY             0
# SECURITY_DELAY               0
# AIRLINE_DELAY                0
# LATE_AIRCRAFT_DELAY          0
# ...

# %%
flights[flights['SCHEDULED_TIME'].isnull()]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 483174   2015      2    1            7      NK            416      N627NK
# 619941   2015      2   10            2      NK            416      N632NK
# 1720237  2015      4   20            1      NK            174      N630NK
# 1820960  2015      4   26            7      NK            720      N614NK
# 2031482  2015      5    9            6      NK            324      N620NK
# 2034453  2015      5   10            7      NK            368      N534NK
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 483174             FLL                 IAG                 2215  ...
# 619941             FLL                 IAG                 2215  ...
# 1720237            FLL                 LGA                 1602  ...
# 1820960            DEN                 DFW                 2059  ...
# 2031482            MCO                 ACY                 2130  ...
# ...

# %%
flights[flights['SCHEDULED_TIME'].isnull()]['CANCELLED'].value_counts()
# Out:
# CANCELLED
# 1    5
# 0    1
# Name: count, dtype: int64

# %%
problem_row = flights[
    (flights['SCHEDULED_TIME'].isnull()) &
    (flights['CANCELLED'] == 0)
]

problem_row
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1720237  2015      4   20            1      NK            174      N630NK
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 1720237            FLL                 LGA                 1602  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 1720237           NaN            NaN         1          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 1720237                  NaN               0.0             0.0            0.0
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 1720237                  0.0            0.0
#
# [1 rows x 31 columns]

# %%
flights[['DEPARTURE_DELAY','ARRIVAL_DELAY','AIR_TIME','DISTANCE']].describe()
# Out:
#        DEPARTURE_DELAY  ARRIVAL_DELAY      AIR_TIME      DISTANCE
# count     5.732926e+06   5.714008e+06  5.714008e+06  5.819079e+06
# mean      9.370158e+00   4.407057e+00  1.135116e+02  8.223565e+02
# std       3.708094e+01   3.927130e+01  7.223082e+01  6.077843e+02
# min      -8.200000e+01  -8.700000e+01  7.000000e+00  2.100000e+01
# 25%      -5.000000e+00  -1.300000e+01  6.000000e+01  3.730000e+02
# 50%      -2.000000e+00  -5.000000e+00  9.400000e+01  6.470000e+02
# 75%       7.000000e+00   8.000000e+00  1.440000e+02  1.062000e+03
# max       1.988000e+03   1.971000e+03  6.900000e+02  4.983000e+03

# %%
flights.to_csv(
    "C:\\Users\\HP\\Desktop\\Downloads\\flights_cleaned.csv"
)

# %% [markdown]
# AIRLINES DATA

# %%
airlines = pd.read_csv("C:\\Users\\HP\\Desktop\\Downloads\\airlines.csv")

# %%
airlines.shape
# Out:
# (14, 2)

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  14 non-null     object
#  1   AIRLINE    14 non-null     object
# dtypes: object(2)
# memory usage: 356.0+ bytes

# %%
airlines.isnull().sum()
# Out:
# IATA_CODE    0
# AIRLINE      0
# dtype: int64

# %%
airlines.duplicated().sum()
# Out:
# np.int64(0)

# %%
airlines['IATA_CODE'].nunique()
# Out:
# 14

# %%
airlines.columns = airlines.columns.str.strip()

airlines['IATA_CODE'] = airlines['IATA_CODE'].str.strip()
airlines['AIRLINE'] = airlines['AIRLINE'].str.strip()

# %%
airlines.to_csv(
    "C:\\Users\\HP\\Desktop\\Downloads\\airlines_cleaned.csv"
)

# %% [markdown]
# AIRPORTS DATA

# %%
airports = pd.read_csv("C:\\Users\\HP\\Desktop\\Downloads\\airports.csv")

# %%
airports.shape
# Out:
# (322, 7)

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  322 non-null    object
#  1   AIRPORT    322 non-null    object
#  2   CITY       322 non-null    object
#  3   STATE      322 non-null    object
#  4   COUNTRY    322 non-null    object
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 17.7+ KB

# %%
airports.duplicated().sum()
# Out:
# np.int64(0)

# %%
airports['IATA_CODE'].nunique()
# Out:
# 322

# %%
airports[
    airports['LATITUDE'].isnull() |
    airports['LONGITUDE'].isnull()
]
# Out:
#     IATA_CODE                                            AIRPORT  \
# 96        ECP    Northwest Florida Beaches International Airport
# 234       PBG                  Plattsburgh International Airport
# 313       UST  Northeast Florida Regional Airport (St. August...
#
#               CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 96     Panama City    FL     USA       NaN        NaN
# 234    Plattsburgh    NY     USA       NaN        NaN
# 313  St. Augustine    FL     USA       NaN        NaN

# %%
airports.columns = airports.columns.str.strip()

# %%
for col in ['IATA_CODE','AIRPORT','CITY','STATE','COUNTRY']:
    airports[col] = airports[col].str.strip()

# %%
airports.to_csv(
    "C:\\Users\\HP\\Desktop\\Downloads\\airports_cleaned.csv"
)
